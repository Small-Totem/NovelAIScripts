# %% [markdown]
# 单抽出ssr!

# %%
# 挂载硬盘
from google.colab import drive
drive.mount('/content/drive')

# %%
# clone webui前端
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui


# 获取novelai的训练权重文件与超参数

# way 1 (hash:925997e9,下载有可能很慢)
#!curl -Lo  models/Stable-diffusion/model.ckpt https://cloudflare-ipfs.com/ipfs/bafybeicpamreyp2bsocyk3hpxr7ixb2g2rnrequub3j2ahrkdxbvfbvjc4/model.ckpt #(4g的模型)
#!cp /content/drive/MyDrive/novelai_script/model_7g/model.ckpt models/Stable-diffusion/model.ckpt #(7g的模型)(似乎不能用)
#!curl -Lo models/Stable-diffusion/animefull-final-pruned.vae.pt https://cloudflare-ipfs.com/ipfs/bafybeiccldswdd3wvg57jhclcq53lvsc6gizasiblwayvhlv6eq4wow7wu/animevae.pt #(naifu的压缩包里面也有)

# way 2 (hash:925997e9)
'''
# %cd /content/
# !apt install -y -qq aria2
# !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z \
  https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
# !echo "Decompressing..."
# !tar xf naifu.tar && rm naifu.tar
# %cd /content/stable-diffusion-webui
# !mv /content/naifu/models/animefull-final-pruned/model.ckpt models/Stable-diffusion/model.ckpt
# !mv /content/naifu/models/animevae.pt models/Stable-diffusion/animefull-final-pruned.vae.pt
'''

# way 3 (name:Anything-V3.0-pruned,hash:2700c435; name:Anything-V3.0,hash:?)
# !apt install -y -qq aria2
# !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z \
  https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-V3.0-pruned.ckpt \
  https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-V3.0.vae.pt
  
  #(没修剪过的似乎会爆内存...实测12.68g不够)
  #https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-V3.0.ckpt \ #hash:6569e224
  
# !mv Anything-V3.0-pruned.ckpt models/Stable-diffusion/Anything-V3.0-pruned.ckpt
# !mv Anything-V3.0.vae.pt models/Stable-diffusion/Anything-V3.0.vae.pt



# !mkdir models/hypernetworks
# !curl -Lo models/hypernetworks/_modules.tar  https://cloudflare-ipfs.com/ipfs/bafybeiduanx2b3mcvxlwr66igcwnpfmk3nc3qgxlpwh6oq6m6pxii3f77e/_modules.tar 
# !tar -xf models/hypernetworks/_modules.tar -C models/hypernetworks/

# 安装依赖环境
# !COMMANDLINE_ARGS="--exit " REQS_FILE="requirements.txt"  python launch.py

# %%
#复制修改的代码
# !cp -f /content/drive/MyDrive/novelai_script/NovelAI_WEBUI/config.json /content/stable-diffusion-webui/config.json
# !cp -f /content/drive/MyDrive/novelai_script/NovelAI_WEBUI/ui-config.json /content/stable-diffusion-webui/ui-config.json
# !cp -f /content/drive/MyDrive/novelai_script/NovelAI_WEBUI/requirements.txt /content/stable-diffusion-webui/requirements.txt #gradio版本升级导致share无效,这行仅用于降版本,等之后修好了考虑删除这行

# %%
# 启动
# !COMMANDLINE_ARGS=" --share --disable-safe-unpickle --gradio-auth me:qwerty" REQS_FILE="requirements.txt" python launch.py
